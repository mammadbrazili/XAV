# %%
import pandas as pd
df = pd.read_excel("/Users/mohammad/XAV/Departemant Media/porsline_cafe.xlsx")
df
# Out:
#     شناسه پاسخ دهنده    City Gender    Age     Morning        Afternoon  \
# 0              vs1sB   بابل      زن  ۱۸-۲۴  صبح تا ظهر  ظهر تا بعدازظهر
# 1              iQndy   تهران     زن  ۱۸-۲۴  صبح تا ظهر  ظهر تا بعدازظهر
# 2              AdNgu     رشت     زن  ۱۸-۲۴         NaN  ظهر تا بعدازظهر
# 3              dbwsG   تهران     زن  ۲۵-۳۴         NaN  ظهر تا بعدازظهر
# 4              RYReT  اصفهان    مرد  ۳۵-۴۴  صبح تا ظهر              NaN
# ..               ...     ...    ...    ...         ...              ...
# 177            q8yGi   تهران     زن  ۲۵-۳۴  صبح تا ظهر  ظهر تا بعدازظهر
# 178            xSMBV   تهران     زن  ۳۵-۴۴  صبح تا ظهر  ظهر تا بعدازظهر
# 179            bQMxO   تهران     زن  ۱۸-۲۴         NaN  ظهر تا بعدازظهر
# 180            pS5MR     کرج    مرد  ۱۸-۲۴  صبح تا ظهر              NaN
# 181            vzPsI   تهران    مرد  ۲۵-۳۴         NaN  ظهر تا بعدازظهر
#
#               Night                      tasteful  \
# 0               NaN  شیرینی سرا-امیر شکلات-میزبان
# ...

# %%
tasteful_df = df[["City", "Gender","Age", "tasteful", "Number" ]]
tasteful_df
# Out:
#        City Gender    Age                      tasteful  Number
# 0     بابل      زن  ۱۸-۲۴  شیرینی سرا-امیر شکلات-میزبان   هفتگی
# 1     تهران     زن  ۱۸-۲۴                        نولان   روزانه
# 2       رشت     زن  ۱۸-۲۴                       قهوه ۲۹   هفتگی
# 3     تهران     زن  ۲۵-۳۴                        کایزن   روزانه
# 4    اصفهان    مرد  ۳۵-۴۴                     گندم کافی  روزانه
# ..      ...    ...    ...                           ...     ...
# 177   تهران     زن  ۲۵-۳۴                       وی کافه   هفتگی
# 178   تهران     زن  ۳۵-۴۴                          مان   روزانه
# 179   تهران     زن  ۱۸-۲۴                       لوگغنیه   هفتگی
# 180     کرج    مرد  ۱۸-۲۴                            سل   هفتگی
# 181   تهران    مرد  ۲۵-۳۴                         نولان   هفتگی
#
# [182 rows x 5 columns]
