# %%
def find_highest_number(input_string):
    # Split the input string into individual elements based on any whitespace
    elements = input_string.split()
    
    # Convert the string elements to floats
    numbers = [float(element) for element in elements]
    
    # Find and return the maximum number
    return max(numbers)

# Example usage:
input_string = """
 18		20	24.5	21.75	15.15		15.75	16.2	25.1		22.9			20.35	15	18.2	20.4		11.5		18.8		19.7	19.9	11.65			8.1	15.15	
17.85		7.8	14.35	21.95	13.45		17.55	19.95	15.25					21.6	17.4	10.1	21.95	15.1	10.35		18.5	22.95		18.85	12.7			12.75	17.9	
13.65		15.1	18.25	15.35	11.65		13.65	16.1	19.2					19.3	16.65	18.9	18.4	21.35	8			21.05	17.6	17.95	4.85			10.3	13.95	
22.6		12.9	16.6		9.9		14.6	8.15			13.3	5.45		20.2	14.85	8.9	25.27	12.4	8.15		21.45	20.85	27.25	15.15	14.3			11.5	10.1	
24.35		17.1	19.6		8.9		13.35	15.55	20.4		21.6	8.45		16.05	23.95	10.75		15.55	9.4		20.6	22.3	24.15	14.9	15.2			10.7	13	
29.4		16.1		22.2	9.7		19.7	21.65	20.75		25.6	6.2		17.45	15.1	7.1	28.9	16.35	10.6		7.65	16.6	21.65	11.75	12.04			7.05	15.2	
14.8		6.7	14.35	17.45	11.3		13.95	16.4	11.6			5.8		19.95	14.25	14	20.1	18.25	6.4		17.05	18.92	16.6	16.57	10.7			11.55	14.15	
21.3		16.65	18.55	24.95	8.4		16.6	21.25	25.05		22.35	5.75		22.55	19.05	18.85		19.25	8.95		14.85	19.95	16.85		14.4					
25.3		15.9	14	21.4	9.85		12.95	15.65	20.65		19	6.3			14.65		23.9	13.45	7.95		18.85	14.15	18.95	13.5	14					
		5.95	7.9	10.65	5.95		6.8	9.25	14.5		13.8	3		16.4	11.25	15.2	16.2		7.85		11.6	15.65	13.25	10.65	9.1			7.25		
																5.8	12.2	7.9	5.25		11.7	10.6	10.9	8.8						
							11.4	12.95	15.6		17	2.5		19.25	12.2	15.05	12.58	11.85	9.85		14.7	20.05	19.05	17.05	14			6.45	14.1	
								6.15	8.4		8.25	4.15		12.45	9.7	6.4	16.3	6.45	5.2		10.1	9.3	12.3	8.75	10.1			9.05	6.4	
																														0
																														0
		5.75	5.7	4.95	1.75		8.45	7.75	3.4		5.75	4.85		7.05	7.35	8.6		7.2	4.3		3.35	4.15	11	5.8	8.3				5.75	
		6.85	7.35	6.1	4.6		6.15	8.45	6		4	4.5			11.1	6.75	14.6	6	4		11.25	9.5	9.5	5.65	7.95			1.4	3.65	
																														0"""

print("The highest number is:", find_highest_number(input_string))
# Out:
# The highest number is: 29.4

# %%
import re

def extract_numbers(input_string):
    # Use regex to find all floating-point numbers in the string
    numbers = re.findall(r'\d+\.\d+', input_string)
    # Convert the extracted numbers from strings to floats
    numbers = [float(number) for number in numbers]
    return numbers

# %%
factory = []
sorter =[]

# %%
factory.append(extract_numbers(""" 

   194.9	199.9	63.8		131.2		108.9	182	160.25	88.5		188.2	241.9	246.7	277.7	175.45	181.25		160.8	313.1	334.25	359.5	190.3	202.05		230.3	184.75	79.3
                               
                               """))
factory
# Out:
# [[187.85,
#   116.75,
#   169.75,
#   114.3,
#   215.5,
#   233.8,
#   313.9,
#   244.65,
#   107.75,
#   216.75,
#   229.75,
#   71.95,
#   205.75,
#   210.7,
#   124.95,
#   117.2,
#   123.95,
#   114.45,
#   75.35,
#   125.85,
#   135.05],
#  [187.85,
#   116.75,
#   169.75,
#   114.3,
#   215.5,
#   233.8,
#   313.9,
#   244.65,
#   107.75,
#   216.75,
#   229.75,
#   71.95,
#   205.75,
#   210.7,
#   124.95,
#   117.2,
#   123.95,
#   114.45,
#   75.35,
#   125.85,
#   135.05],
#  [92.65,
#   123.9,
#   68.2,
#   91.14,
#   152.4,
#   152.25,
#   168.25,
#   155.3,
#   82.75,
#   80.95,
#   103.25,
#   38.75,
#   136.6,
#   117.15,
#   173.4,
#   77.65,
#   111.2,
#   38.75,
#   114.8,
#   91.6,
#   175.5,
#   119.9,
#   47.55],
#  [139.2,
#   91.5,
#   147.3,
#   106.65,
#   126.35,
#   188.9,
#   123.7,
#   146.65,
#   205.85,
#   154.15,
#   98.1,
#   136.25,
#   124.5,
#   180.8,
#   42.6,
#   165.5,
#   173.9,
#   143.15,
#   231.45,
#   177.7,
#   84.15,
#   208.2,
# ...

# %%
sorter.append(extract_numbers("""  

23.45	23.4			15.25		16.3	19	20.1	9.2		25.45	28.1	25.15					28.8	25.5	35.45	32.75	23.6	17.15		30.25	19.75	14.35
21.45	20.5	7.2		18.2			14.05	18.4	9.15		23.35	26.45	30.45	26.7	21.35	20.9		19.95	20.25	25.42	21	17.5	15.1		18.8		
17.7	19.45	6.2		11.7		13.5	18.9	16.9	7.95		23.05	24	22.8	20.15	24.4	19.1			18.8	27.3	16.35	18	12.4		22.45		
19.75	21.45	8.9				16.1	21.15	16.35	10.4		26.14	23.95	26.7	30.85	36.8	25.8			28.4	37.45	41.4	25.2	13.8		30.9	19.65	16.75
14.2	14.65	5.8				11.65	10.7	14.3	6.55		19.55	22.7	22.85	21.75	20.9	12.3		19.75	13.45		21.75	16.45	16.7		22.5	19.8	10
23.9	22.25	6.65		9.95			12.95	20	10.95		23.05	8.8	20.2	28.8	32.5	23.05		31.4	25.05	27.45	40.9	28.5	31.75		22.7	26.4	12.7
17.15	17.15	5.75		17.6		13.05	13	15.9	6.7		18.1	20.3	20.9	18.55	24.2	17		20.95	19	25.4	23.35	18.45	14.45		19.5	13.15	
17.05	16.65	5.75		17.5		17.15	22.5	9.85	7.05		10.55	21.05	10.35	20.1	23.05	17.6		20.5	16.15	19.25	19.85	15.25	12.45		17.65	19.2	7.3
17.35	19.95	6.65				15.25	17.15		7.55		16.2	16.25	34.8	23.55	13.5	20.05		22.7	18.45	16.35	28.8	14.35	5.45		22.2	13.9	12.2
	1.55	5.15		3.9			7.3		4.5			4.25	8.75	8.05	6.25	2.8		2.75	4.65				7.4			1.8	
12.3	10	3.75		9.45		11.3	12.9	9.85	4.55		14.3	17.9	17.55	17.35	17.7	12.25		17.35	14	13.75	18.55	13.75	12.95		15.05	15.8	
2.65	1.35																										
7.7	11.75	2.05		6.2		5.15	4.65	5.95	2.55		6	9.1	5.25	9.15	8.8	9.2		6.9	2.4			8.05	2				
																						21.2	12.45		31.7	24.25	16.05

"""))

# %%
factory_list = []

# Iterate through each sublist in the list of lists
for sublist in factory:
    # Extend the all_numbers list with the numbers from the current sublist
    factory_list.extend(sublist)

# all_numbers now contains all the numbers from the non-empty sublists
print(len(factory_list))
# Out:
# 237

# %%
factory_list
# Out:
# [187.85,
#  116.75,
#  169.75,
#  114.3,
#  215.5,
#  233.8,
#  313.9,
#  244.65,
#  107.75,
#  216.75,
#  229.75,
#  71.95,
#  205.75,
#  210.7,
#  124.95,
#  117.2,
#  123.95,
#  114.45,
#  75.35,
#  125.85,
#  135.05,
#  187.85,
#  116.75,
#  169.75,
#  114.3,
#  215.5,
#  233.8,
#  313.9,
#  244.65,
#  107.75,
#  216.75,
#  229.75,
#  71.95,
#  205.75,
#  210.7,
#  124.95,
#  117.2,
#  123.95,
#  114.45,
#  75.35,
#  125.85,
#  135.05,
#  92.65,
#  123.9,
#  68.2,
#  91.14,
#  152.4,
#  152.25,
#  168.25,
#  155.3,
#  82.75,
#  80.95,
#  103.25,
#  38.75,
#  136.6,
#  117.15,
#  173.4,
#  77.65,
#  111.2,
#  38.75,
#  114.8,
#  91.6,
#  175.5,
#  119.9,
#  47.55,
#  139.2,
#  91.5,
#  147.3,
#  106.65,
#  126.35,
#  188.9,
#  123.7,
#  146.65,
#  205.85,
#  154.15,
#  98.1,
#  136.25,
#  124.5,
#  180.8,
#  42.6,
#  165.5,
#  173.9,
#  143.15,
#  231.45,
#  177.7,
#  84.15,
#  208.2,
#  114.95,
#  164.9,
#  120.6,
#  50.9,
#  96.75,
#  104.4,
#  240.65,
#  145.7,
#  119.9,
# ...

# %%
sorter_list = []

# Iterate through each sublist in the list of lists
for sublist in sorter:
    # Extend the all_numbers list with the numbers from the current sublist
    sorter_list.extend(sublist)

# all_numbers now contains all the numbers from the non-empty sublists
print(len(sorter_list))
# Out:
# 2175

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def distribution(data, title, bins=30, color='blue', save_path=None):
    """
    Create and display a histogram and density plot of the given data,
    including lines for the mean and standard deviation.

    Parameters:
    - data: List of numerical values.
    - title: Title for the plots.
    - bins: Number of bins for the histogram (default is 30).
    - color: Color for the plots (default is 'blue').
    - save_path: If provided, save the plots to this file path (default is None).
    """

    # Check if data is a list of numbers
    if not all(isinstance(i, (int, float)) for i in data):
        raise ValueError("Data should be a list of numerical values.")

    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data)
    print(mean)

    # Create a histogram
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=bins, alpha=0.7, color=color, edgecolor='black')
    mean_line = plt.axvline(mean, color='red', linestyle='dashed', linewidth=1)
    std_dev_plus_line = plt.axvline(mean + std_dev, color='green', linestyle='dashed', linewidth=1)
    std_dev_minus_line = plt.axvline(mean - std_dev, color='green', linestyle='dashed', linewidth=1)
    plt.title(f'Histogram of {title}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend([mean_line, std_dev_plus_line, std_dev_minus_line], ['Mean', '+1 Std Dev', '-1 Std Dev'])
    if save_path:
        plt.savefig(f"{save_path}_histogram.png")
    plt.show()

    # Create a density plot
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data, shade=True, color=color)
    mean_line = plt.axvline(mean, color='red', linestyle='dashed', linewidth=1)
    std_dev_plus_line = plt.axvline(mean + std_dev, color='green', linestyle='dashed', linewidth=1)
    std_dev_minus_line = plt.axvline(mean - std_dev, color='green', linestyle='dashed', linewidth=1)
    plt.title(f'Density Plot of {title}')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.legend([mean_line, std_dev_plus_line, std_dev_minus_line], ['Mean', '+1 Std Dev', '-1 Std Dev'])
    if save_path:
        plt.savefig(f"{save_path}_density.png")
    plt.show()

    # Create both plots together
    plt.figure(figsize=(10, 6))
    sns.histplot(data, bins=bins, kde=True, color=color, edgecolor='black')
    mean_line = plt.axvline(mean, color='red', linestyle='dashed', linewidth=1)
    std_dev_plus_line = plt.axvline(mean + std_dev, color='green', linestyle='dashed', linewidth=1)
    std_dev_minus_line = plt.axvline(mean - std_dev, color='green', linestyle='dashed', linewidth=1)
    plt.title(f'Histogram and Density Plot of {title}')
    plt.xlabel('Value')
    plt.ylabel('Frequency / Density')
    plt.legend([mean_line, std_dev_plus_line, std_dev_minus_line], ['Mean', '+1 Std Dev', '-1 Std Dev'])
    if save_path:
        plt.savefig(f"{save_path}_combined.png")
    plt.show()

# Example usage
# distribution([1, 2, 3, 4, 5], "Sample Data", bins=5, color='green', save_path='output_plot')

# %%
distribution(sorter_list,"")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mohammad/Documents/GitHub/XAV/blank.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> distribution(sorter_list,"")
#
# NameError: name 'sorter_list' is not defined

# %%
distribution(factory_list,"")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mohammad/Documents/GitHub/XAV/blank.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> distribution(factory_list,"")
#
# NameError: name 'factory_list' is not defined

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("/Users/mohammad/Dropbox/XAV Finance (1)/گزارشات/1403/فروردین/نرخ تولید 1402.xlsx",sheet_name="gb-roast")[:-2].T.iloc[1:]

def rate(df,string):
    # Getting coffee names 
    coffee_list = df.columns.to_list()


    # calculating gb-roast for each month of each line
    for col in range(1, df.shape[1]):
        if col % 2 == 1:  # Check if column index is odd
            prev_col = col - 1  # Get the previous column index
            df[col] = df[col] / df[prev_col]

    # calculating total green bean of each line
    even_column_sum = df.iloc[:, ::2].sum(axis=1)

    # Divide all even columns by their corresponding sum of even columns
    even_columns = df.iloc[:, ::2]
    df.iloc[:, ::2] = even_columns.div(even_column_sum, axis=0)

    # Add the sum as a new column
    df['each_line_sum'] = even_column_sum

    #calculating weighted rate of each line 
    rate_list =[]
    for i in range(0,len(df.index.to_list())):
        row_index = i
        row_values = df.iloc[row_index].tolist()
        # Deleting NAN
        cleaned_list = [x for x in row_values if pd.notna(x)]
        # Deleting sum value of each line in calculations
        value_list = cleaned_list[:-1]
        # portion of green bean list
        even_list = value_list[: :2]
        # rate from grean bean to sorted bean in each month of line
        odd_list = value_list[: :-2]

        # calculating weighted rate
        rate = 0
        for i in range(0,len(odd_list)):
            rate += (even_list[i] * odd_list[i])

        # adding to list 
        rate_list.append(rate)
        rate_list

    # adding to dataframe
    df["line_weighted_rate"] = rate_list

    # calculatng portion of eachline based on total grean bean
    df["each_line_portion"] = None
    total_kg = sum(df["each_line_sum"].to_list())

    for i in df.index.to_list():
        df.loc[i,"each_line_portion"] = df.loc[i,"each_line_sum"] / total_kg

    # calculatng weighted grean bean to roast rate 
    list1 = df["line_weighted_rate"].to_list()
    list2 = df["each_line_portion"].to_list()
    # Multiply corresponding elements from list1 and list2 and sum the results
    df["each_line_multiplication"] = None
    total_multiplication = 0
    for i in range(len(list1)):
        total_multiplication += list1[i] * list2[i]

    print((total_multiplication))
    df.to_excel(f"{string}.xlsx")


rate(df,"gb-roast")

df = pd.read_excel("/Users/mohammad/Dropbox/XAV Finance (1)/گزارشات/1403/فروردین/نرخ تولید 1402.xlsx",sheet_name="roast-sort")[:-2].T.iloc[1:]
rate(df,"roast-sort1")

df = pd.read_excel("/Users/mohammad/Dropbox/XAV Finance (1)/گزارشات/1403/فروردین/نرخ تولید 1402.xlsx",sheet_name="sort-manualsort")[:-2].T.iloc[1:]
rate(df,"sort1-sort2")
# Out:
# 0.8607389593539989
# 0.9705128982266189
# 0.9271652520493721

# %%
import pandas as pd
import numpy as np 

dataset = pd.read_excel("/Users/mohammad/Dropbox/XAV Finance (1)/گزارشات/1403/اردیبهشت/اطلاعات قهوه.xlsx").iloc[:26]
total_roast = sum(df["each_line_sum"].to_list())

def filter(Metric):

    series_dict = {}
    for i in set(dataset[Metric].to_list()):
        gf = dataset[dataset[Metric] == i]
        total_kg = sum(gf["each_line_sum"] .to_list())
        total_share = total_kg / total_roast
        gb_roast_defect_rate = np.mean(gf["gb_roast_defect_rate"].to_list())
        gb_roast_baha = np.mean(gf["gb_roast_baha"].to_list())
        roast_sort1_defect_rate = np.mean(gf["roast_sort1_defect_rate"].to_list())
        roast_sort1_baha = np.mean(gf["roast_sort1_baha"].to_list())
        sort1_sort2_defect_rate = np.mean(gf["sort1_sort2_defect_rate"].to_list())
        sort1_sort2_baha = np.mean(gf["sort1_sort2_baha"].to_list())
        gb_pack_defect_rate = np.mean(gf["gb_pack_defect_rate"].to_list())
        gb_pack_baha = np.mean(gf["gb_pack_baha"].to_list())
        roasted =  np.mean(gf["Roasted"].to_list())
        sorted =  np.mean(gf["Sorted"].to_list())
        sorted_2 =  np.mean(gf["Sorted2"].to_list())

        line = len(gf)

        series_dict[i] = [line,total_kg,total_share,gb_roast_defect_rate,gb_roast_baha,roast_sort1_defect_rate,roast_sort1_baha,
                        sort1_sort2_defect_rate,sort1_sort2_baha,gb_pack_defect_rate,gb_pack_baha,roasted,sorted,sorted_2]

        final = pd.DataFrame(series_dict).T
        final.columns = ['lines', 'Total_GB', 'Share_of_Total', '‌GB_Roast', 'GB_Roast_Baha', 'Roast_Sort1',
              'Roast_Sort1_Baha', 'Sort1_Sort2', 'Sort1_Sort2_baha', 'GB_Final', 'GB_Final_Baha',"roasted","sorted","sorted_2"]

    return final

filter("Name")
# Out:
#                   lines  Total_GB  Share_of_Total  ‌GB_Roast  GB_Roast_Baha  \
# Cascaritas          1.0    137.47        0.002754   0.859600       0.163332
# Gaylee              1.0     72.99        0.001462   0.854427       0.170375
# La Cereza           1.0     34.30        0.000687   0.845196       0.183157
# Fuji                1.0    299.08        0.005991   0.854925       0.169694
# Sidamo              1.0   3652.00        0.073155   0.865394       0.155542
# Hambella            1.0   4198.00        0.084092   0.863119       0.158589
# Bombougo            1.0      8.40        0.000168   0.850000       0.176471
# Montana             1.0    349.59        0.007003   0.848840       0.178079
# Hamasho             1.0    139.60        0.002796   0.841863       0.187842
# Kiawamurur          1.0    147.96        0.002964   0.855996       0.168230
# Peru Huancayo       1.0   5570.00        0.111575   0.856173       0.167988
# ...

# %%
filter(df,"Series")
# Out:
#    lines  total_kg  total_share  gb_roast_defect_rate  gb_roast_baha  \
# A   14.0   2805.36     0.056195              0.854287       0.170645
# V   10.0  47116.21     0.943805              0.857867       0.165780
#
#    roast_sort1_defect_rate  roast_sort1_baha  sort1_sort2_defect_rate  \
# A                 0.977021          0.024629                 0.915638
# V                 0.972355          0.028915                 0.905875
#
#    sort1_sort2_baha  gb_pack_defect_rate  gb_pack_baha
# A          0.093906             0.764502      0.312582
# V          0.109083             0.755928      0.330946

# %%
def series():
    df = filter(df,"Series")
    x = df.index.to_list()
    total_kg = df["total_kg"].to_list()

# %%
dataset = pd.read_excel("/Users/mohammad/Dropbox/XAV Finance (1)/گزارشات/1403/اردیبهشت/اطلاعات قهوه.xlsx").iloc[:26]




#--------------------------------------------------------- Functions Defining ---------------------------------------------------------------
total_roast = sum(dataset["each_line_sum"].to_list())

def filter(Metric):

    series_dict = {}
    for i in set(dataset[Metric].to_list()):
        gf = dataset[dataset[Metric] == i]
        total_kg = sum(gf["each_line_sum"] .to_list())
        total_share = total_kg / total_roast
        gb_roast_defect_rate = np.mean(gf["gb_roast_defect_rate"].to_list())
        gb_roast_baha = np.mean(gf["gb_roast_baha"].to_list())
        roast_sort1_defect_rate = np.mean(gf["roast_sort1_defect_rate"].to_list())
        roast_sort1_baha = np.mean(gf["roast_sort1_baha"].to_list())
        sort1_sort2_defect_rate = np.mean(gf["sort1_sort2_defect_rate"].to_list())
        sort1_sort2_baha = np.mean(gf["sort1_sort2_baha"].to_list())
        gb_pack_defect_rate = np.mean(gf["gb_pack_defect_rate"].to_list())
        gb_pack_baha = np.mean(gf["gb_pack_baha"].to_list())
        line = len(gf)

        series_dict[i] = [line,total_kg,total_share,gb_roast_defect_rate,gb_roast_baha,roast_sort1_defect_rate,roast_sort1_baha,
                        sort1_sort2_defect_rate,sort1_sort2_baha,gb_pack_defect_rate,gb_pack_baha]

        final = pd.DataFrame(series_dict).T
        final.columns = ['lines', 'Total_GB', 'Share_of_Total', '‌GB_Roast', 'GB_Roast_Baha', 'Roast_Sort1',
              'Roast_Sort1_Baha', 'Sort1_Sort2', 'Sort1_Sort2_baha', 'GB_Final', 'GB_Final_Baha']

    return final

a = filter("Country")
a
# Out:
#              lines  Total_GB  Share_of_Total  ‌GB_Roast  GB_Roast_Baha  \
# Costa Rica     1.0    203.64        0.004079   0.860329       0.162346
# Panama         2.0   1265.00        0.025340   0.865120       0.155945
# Vortex         1.0  17692.00        0.354396   0.858456       0.164883
# Kenya          2.0    292.96        0.005868   0.855523       0.168876
# Colombia       4.0   1963.04        0.039322   0.847039       0.180594
# El Salvador    1.0    349.59        0.007003   0.848840       0.178079
# Brazil         1.0   8299.00        0.166241   0.862440       0.159501
# Rwanada        1.0    299.08        0.005991   0.854925       0.169694
# Ethipoia       8.0  13781.39        0.276061   0.856378       0.167843
# Honduras       1.0    137.47        0.002754   0.859600       0.163332
# Guatmala       1.0     68.40        0.001370   0.857450       0.166249
# Peru           1.0   5570.00        0.111575   0.856173       0.167988
#
# ...

# %%
def plot(column_name, df):
    # Create a figure and axis
    plt.bar(figsize=(8, 6))

    plt.show()

# %%
plot("Total_GB",a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mohammad/Documents/GitHub/XAV/blank.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> plot("Total_GB",a)
#
# /Users/mohammad/Documents/GitHub/XAV/blank.ipynb Cell 22 line 3
#       <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> def plot(column_name, df):
#       <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a>     # Create a figure and axis
# ----> <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a>     plt.bar(figsize=(8, 6))
#       <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a>     plt.show()
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = filter("Name")

# %%
import matplotlib.pyplot as plt
import random

def plot_stacked_with_ratios(df):
    # Sample data
    categories = df.index
    fig, ax = plt.subplots(figsize=(12, 8))

    # Initialize bottom values for stacking
    bottom = [0] * len(categories)

    # Set the colors for each stacked value
    colors = ['#ADD8E6', '#87CEEB', '#6495ED', '#4169E1']

    column_order = ['Total_GB', 'roasted', 'sorted', 'sorted_2']

    for i, col in enumerate(column_order):
        values = df[col].to_list()
        bars = ax.bar(categories, values, bottom=bottom, color=colors[i], label=col)
        bottom = [sum(x) for x in zip(bottom, values)]

        # Calculate and display the ratio in the middle of each stack
        for j, bar in enumerate(bars):
            total_height = sum(df.iloc[j].values)
            ratio = values[j] / total_height if total_height != 0 else 0
            ax.text(bar.get_x() + bar.get_width() / 2, bottom[j] - values[j] / 2, f'{ratio:.2f}', ha='center', va='center', color='white')

    # Rotate the x-axis labels for better readability
    plt.xticks(rotation=45, ha='right', fontsize=12)
    ax.tick_params(axis='y', labelsize=12)

    # Add a legend
    ax.legend()

    plt.show()

# Example usage:
# Assuming df is your DataFrame with 'Total_GB', 'roasted', 'sorted', 'sorted_2' columns
plot_stacked_with_ratios(df[['Total_GB', 'roasted', 'sorted', 'sorted_2']])

# %%
import matplotlib.pyplot as plt

# Sample data for three categories
categories = df.index
values1 = df["roasted"].to_list()
values2 = df["sorted"].to_list()
values3 = df["sorted_2"].to_list()

# Create the figure and axis
fig, ax = plt.subplots()

# Plot the stacked bars
ax.bar(categories, values1, label='Value 1')
ax.bar(categories, values2, bottom=values1, label='Value 2')
ax.bar(categories, values3, bottom=[sum(x) for x in zip(values1, values2)], label='Value 3')

# Add labels, title, and legend
ax.set_ylabel('Values')
ax.set_title('Stacked Bar Chart with 3 Columns of Data')
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data
steps = ['Green bean', 'Roast', 'Sort', 'Sort2']
values = [100, 80, 60, 50]

# Create the figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Create the stacked bar plot
ax.bar(steps, values, color=['green', 'brown', 'gray', 'black'])

# Set the title and axis labels
ax.set_title('Funnel Plot')
ax.set_xlabel('Steps')
ax.set_ylabel('Values')

# Set the x-axis tick labels to be rotated
plt.xticks(rotation=45, ha='right')

# Add labels to each bar
for i, v in enumerate(values):
    ax.text(i, v + 2, str(v), ha='center')

# Adjust the spacing between subplots
plt.subplots_adjust(bottom=0.2)

# Display the plot
plt.show()

# %%
import plotly.express as px
import pandas as pd
import nbformat

# Sample data
df = pd.DataFrame(dict(
    stage = ['Sent', 'Received', 'Clicks', 'Sales'],
    percentage = [100, 70, 30, 10]
))

# Create a basic funnel chart
fig = px.funnel(df, x='percentage', y='stage', title="Funnel Chart")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mohammad/Documents/GitHub/XAV/blank.ipynb Cell 28 line 1
#      <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a> # Create a basic funnel chart
#      <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X41sZmlsZQ%3D%3D?line=11'>12</a> fig = px.funnel(df, x='percentage', y='stage', title="Funnel Chart")
# ---> <a href='vscode-notebook-cell:/Users/mohammad/Documents/GitHub/XAV/blank.ipynb#X41sZmlsZQ%3D%3D?line=12'>13</a> fig.show()
#
# File ~/Documents/GitHub/XAV/.venv/lib/python3.11/site-packages/plotly/basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
# ...
