# %%
import json

# %%
with open('posts.json', 'r') as file:
    data = json.load(file)

# Pretty print the JSON data
print(json.dumps(data, indent=4))
# Out:
# {
#     "organic_insights_posts": [
#         {
#             "title": "",
#             "media_map_data": {
#                 "Media Thumbnail": {
#                     "uri": "media/other/432754832_770813168321643_1108622561460602196_n_18344029192103586.jpg",
#                     "creation_timestamp": 1710844534,
#                     "media_metadata": {
#                         "photo_metadata": {
#                             "exif_data": [
#                                 {
#                                     "scene_capture_type": "standard",
#                                     "device_id": "EEB9F84A-2EB6-4E2A-A064-A371F1EA5421",
#                                     "camera_position": "unknown",
#                                     "source_type": "library"
#                                 }
#                             ]
#                         },
#                         "camera_metadata": {
#                             "has_camera_metadata": false
# ...
